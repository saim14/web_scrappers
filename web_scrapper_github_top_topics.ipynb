# %% [markdown]
# # Import all libraries

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scrape topic list and write a csv file
# #### Store name of the topic, description and topic url first for further use to scrape individual topics related information

# %%
topics_url = 'https://github.com/topics'
response = requests.get(topics_url)
response.status_code
# Out:
# 200

# %%
page_contents = response.text
len(page_contents)
# Out:
# 126394

# %%
# saving html file
with open('webpage.html', 'w') as f:
    f.write(page_contents)

# %%
doc = BeautifulSoup(page_contents, 'html.parser')

# %%
selection_class = 'f3 lh-condensed mb-0 mt-1 Link--primary'
topic_title_tags = doc.find_all('p', {'class':selection_class})

# %%
desc_selector = 'f5 color-text-secondary mb-0 mt-1'
topic_desc_tags = doc.find_all('p', {'class': desc_selector})

# %%
topic_link_selector = 'd-flex no-underline'
topic_link_tags = doc.find_all('a', {'class':topic_link_selector})

# %%
# we will use them later in final scrapping
topic_titles = []
for tag in topic_title_tags:
    topic_titles.append(tag.text)
print(topic_titles)
# Out:
# ['3D', 'Ajax', 'Algorithm', 'Amp', 'Android', 'Angular', 'Ansible', 'API', 'Arduino', 'ASP.NET', 'Atom', 'Awesome Lists', 'Amazon Web Services', 'Azure', 'Babel', 'Bash', 'Bitcoin', 'Bootstrap', 'Bot', 'C', 'Chrome', 'Chrome extension', 'Command line interface', 'Clojure', 'Code quality', 'Code review', 'Compiler', 'Continuous integration', 'COVID-19', 'C++']

# %%
topic_descs = []

for tag in topic_desc_tags:
    topic_descs.append(tag.text.strip())
    
topic_descs[:2]
# Out:
# ['3D modeling is the process of virtually developing the surface and structure of a 3D object.',
#  'Ajax is a technique for creating interactive web applications.']

# %%
# # we will use them later in final scrapping
topic_urls = []
base_url = 'https://github.com'

for tag in topic_link_tags:
    topic_urls.append(base_url + tag['href'])
    
topic_urls[:5]
# Out:
# ['https://github.com/topics/3d',
#  'https://github.com/topics/ajax',
#  'https://github.com/topics/algorithm',
#  'https://github.com/topics/amphp',
#  'https://github.com/topics/android']

# %%
topics_dict = {
    'title':topic_titles,
    'description':topic_descs,
    'url': topic_urls
}

# %%
topics_df = pd.DataFrame(topics_dict)

# %%
topics_df.to_csv('topics.csv', index=None)

# %% [markdown]
# ## Now lets scrape individual topics related data
# - username
# - reponame
# - repolink
# - star

# %%
def parse_star_count(stars_str):
    stars_str = stars_str.strip()
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1]) * 1000)
    return int(stars_str)

def scrape_and_save(topic_url, title):
    response = requests.get(topic_url)
    code = response.status_code
    if code!=200:
        print("Something wrong! Response is unsuccessful")
        return
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    
    h1_selection_class = 'f3 color-text-secondary text-normal lh-condensed'
    repo_tags = topic_doc.find_all('h1', {'class': h1_selection_class})
    
    username = []
    reponame = []
    repourl = []
    star = []
    
    for repo_tag in repo_tags:
        a_tags = repo_tag.find_all('a')
        username.append(a_tags[0].text.strip())
        reponame.append(a_tags[1].text.strip())
        base_url = 'https://github.com'
        repo_url = base_url + a_tags[1]['href']
        repourl.append(repo_url)
        
    star_tags = topic_doc.find_all('a', { 'class': 'social-count float-none'})
    for star_tag in star_tags:
        star_count = parse_star_count(star_tag.text.strip())
        star.append(star_count)
        
    topic_repo_dict = {
    'title':title,
    'username':username,
    'reponame': reponame,
    'repourl':repourl,
    'star': star
    }
    topic_repo_df = pd.DataFrame(topic_repo_dict)
    topic_repo_df.to_csv(f'repo_data/{title}.csv', index=None)
    return topic_repo_df

# %%
scrape_and_save('https://github.com/topics/3d','3d')
# Out:
#    title          username                       reponame  \
# 0     3d            mrdoob                       three.js
# 1     3d            libgdx                         libgdx
# 2     3d         BabylonJS                     Babylon.js
# 3     3d            pmndrs              react-three-fiber
# 4     3d          aframevr                         aframe
# 5     3d             ssloy                   tinyrenderer
# 6     3d           lettier  3d-game-shaders-for-beginners
# 7     3d           FreeCAD                        FreeCAD
# 8     3d         metafizzy                           zdog
# 9     3d          CesiumGS                         cesium
# 10    3d      a1studmuffin             SpaceshipGenerator
# 11    3d       timzhang642            3D-Machine-Learning
# 12    3d          spritejs                       spritejs
# 13    3d  tensorspace-team                    tensorspace
# 14    3d         intel-isl                         Open3D
# 15    3d           jagenjo                 webglstudio.js
# 16    3d      AaronJackson                            vrn
# 17    3d           YadiraF                          PRNet
# 18    3d          openscad                       openscad
# 19    3d           domlysz                     BlenderGIS
# 20    3d             ssloy                  tinyraytracer
# 21    3d             mosra                         magnum
# 22    3d         cleardusk                          3DDFA
# 23    3d   gfxfundamentals             webgl-fundamentals
# 24    3d         jasonlong        isometric-contributions
# 25    3d            google                   model-viewer
# 26    3d           blender                        blender
# 27    3d            antvis                             L7
# 28    3d           pissang                         claygl
# 29    3d     tinyobjloader                  tinyobjloader
#
#                                               repourl   star
# 0                  https://github.com/mrdoob/three.js  70200
# 1                    https://github.com/libgdx/libgdx  18400
# 2             https://github.com/BabylonJS/Babylon.js  13900
# 3         https://github.com/pmndrs/react-three-fiber  13100
# 4                  https://github.com/aframevr/aframe  12700
# 5               https://github.com/ssloy/tinyrenderer  10600
# 6   https://github.com/lettier/3d-game-shaders-for...   9800
# 7                  https://github.com/FreeCAD/FreeCAD   9300
# 8                   https://github.com/metafizzy/zdog   8400
# 9                  https://github.com/CesiumGS/cesium   7000
# 10  https://github.com/a1studmuffin/SpaceshipGener...   6700
# 11  https://github.com/timzhang642/3D-Machine-Lear...   6500
# 12               https://github.com/spritejs/spritejs   4500
# 13    https://github.com/tensorspace-team/tensorspace   4400
# 14                https://github.com/intel-isl/Open3D   4400
# 15          https://github.com/jagenjo/webglstudio.js   4300
# 16                https://github.com/AaronJackson/vrn   4300
# 17                   https://github.com/YadiraF/PRNet   4300
# 18               https://github.com/openscad/openscad   4000
# 19              https://github.com/domlysz/BlenderGIS   3800
# 20             https://github.com/ssloy/tinyraytracer   3700
# 21                    https://github.com/mosra/magnum   3500
# 22                 https://github.com/cleardusk/3DDFA   3000
# 23  https://github.com/gfxfundamentals/webgl-funda...   3000
# 24  https://github.com/jasonlong/isometric-contrib...   2900
# 25             https://github.com/google/model-viewer   2900
# 26                 https://github.com/blender/blender   2500
# 27                       https://github.com/antvis/L7   2300
# 28                  https://github.com/pissang/claygl   2200
# 29     https://github.com/tinyobjloader/tinyobjloader   2200

# %% [markdown]
# ## Now it's time to scrape all of them

# %%
for topic_title, topic_url in zip(topic_titles, topic_urls):
    print(topic_title, topic_url)
    print(f"The topic {topic_title} is scrapping.......")
    scrape_and_save(topic_url,topic_title)
    print(f"The topic {topic_title} is scrapped and saved sucessfully :)")
# Out:
# 3D https://github.com/topics/3d
# The topic 3D is scrapping.......
# The topic 3D is scrapped and saved sucessfully :)
# Ajax https://github.com/topics/ajax
# The topic Ajax is scrapping.......
# The topic Ajax is scrapped and saved sucessfully :)
# Algorithm https://github.com/topics/algorithm
# The topic Algorithm is scrapping.......
# The topic Algorithm is scrapped and saved sucessfully :)
# Amp https://github.com/topics/amphp
# The topic Amp is scrapping.......
# The topic Amp is scrapped and saved sucessfully :)
# Android https://github.com/topics/android
# The topic Android is scrapping.......
# The topic Android is scrapped and saved sucessfully :)
# Angular https://github.com/topics/angular
# The topic Angular is scrapping.......
# The topic Angular is scrapped and saved sucessfully :)
# Ansible https://github.com/topics/ansible
# The topic Ansible is scrapping.......
# The topic Ansible is scrapped and saved sucessfully :)
# API https://github.com/topics/api
# The topic API is scrapping.......
# The topic API is scrapped and saved sucessfully :)
# Arduino https://github.com/topics/arduino
# The topic Arduino is scrapping.......
# The topic Arduino is scrapped and saved sucessfully :)
# ASP.NET https://github.com/topics/aspnet
# The topic ASP.NET is scrapping.......
# The topic ASP.NET is scrapped and saved sucessfully :)
# Atom https://github.com/topics/atom
# The topic Atom is scrapping.......
# The topic Atom is scrapped and saved sucessfully :)
# Awesome Lists https://github.com/topics/awesome
# The topic Awesome Lists is scrapping.......
# The topic Awesome Lists is scrapped and saved sucessfully :)
# Amazon Web Services https://github.com/topics/aws
# The topic Amazon Web Services is scrapping.......
# The topic Amazon Web Services is scrapped and saved sucessfully :)
# Azure https://github.com/topics/azure
# The topic Azure is scrapping.......
# The topic Azure is scrapped and saved sucessfully :)
# Babel https://github.com/topics/babel
# The topic Babel is scrapping.......
# The topic Babel is scrapped and saved sucessfully :)
# Bash https://github.com/topics/bash
# The topic Bash is scrapping.......
# The topic Bash is scrapped and saved sucessfully :)
# Bitcoin https://github.com/topics/bitcoin
# The topic Bitcoin is scrapping.......
# The topic Bitcoin is scrapped and saved sucessfully :)
# Bootstrap https://github.com/topics/bootstrap
# The topic Bootstrap is scrapping.......
# The topic Bootstrap is scrapped and saved sucessfully :)
# Bot https://github.com/topics/bot
# The topic Bot is scrapping.......
# The topic Bot is scrapped and saved sucessfully :)
# C https://github.com/topics/c
# The topic C is scrapping.......
# The topic C is scrapped and saved sucessfully :)
# Chrome https://github.com/topics/chrome
# The topic Chrome is scrapping.......
# The topic Chrome is scrapped and saved sucessfully :)
# Chrome extension https://github.com/topics/chrome-extension
# The topic Chrome extension is scrapping.......
# The topic Chrome extension is scrapped and saved sucessfully :)
# Command line interface https://github.com/topics/cli
# The topic Command line interface is scrapping.......
# The topic Command line interface is scrapped and saved sucessfully :)
# Clojure https://github.com/topics/clojure
# The topic Clojure is scrapping.......
# The topic Clojure is scrapped and saved sucessfully :)
# Code quality https://github.com/topics/code-quality
# The topic Code quality is scrapping.......
# The topic Code quality is scrapped and saved sucessfully :)
# Code review https://github.com/topics/code-review
# The topic Code review is scrapping.......
# The topic Code review is scrapped and saved sucessfully :)
# Compiler https://github.com/topics/compiler
# The topic Compiler is scrapping.......
# The topic Compiler is scrapped and saved sucessfully :)
# Continuous integration https://github.com/topics/continuous-integration
# The topic Continuous integration is scrapping.......
# The topic Continuous integration is scrapped and saved sucessfully :)
# COVID-19 https://github.com/topics/covid-19
# The topic COVID-19 is scrapping.......
# The topic COVID-19 is scrapped and saved sucessfully :)
# C++ https://github.com/topics/cpp
# The topic C++ is scrapping.......
# The topic C++ is scrapped and saved sucessfully :)
